# %% [markdown]
# # CACEIS Human Capital Valuation
#
# This notebook computes the V_HC composite index for all 26 CACEIS Business Units.
#
# **Pipeline:**
# 1. Load raw HR Excel files (Training, EAE, Absenteeism, IMR, NBI/FTE)
# 2. Compute KPIs (Y, λ, β, P, ρ) per BU
# 3. Normalise and apply V_HC weights
# 4. Export `rag/data/kpi-output.json`
#
# **Prerequisites:** Source files in `Sujet Alberthon/` (confidential, not included in repo).
#
# See `interface/data/generate-kpi.py` for the standalone script version.

# %%
# See interface/data/generate-kpi.py for the full implementation
# This notebook is a placeholder — replace with the full pipeline
